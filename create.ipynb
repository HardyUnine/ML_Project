# %%
import pandas as pd
# from simulate import simulate_days  # Import your simulation function from your module
from simulate import simulate_days
# from simulate import simulate_days as old_simulate_days
import os
folder = 'data'

# %% [markdown]
# ## AMC

# %%
seed_amc = {
    'DAY': 0,
    'TICKER': 'AMC',
    'COMPANY_NAME': 'AMC Entertainment Holdings',
    'TOTAL_SHARES': 200000000,
    'SHORTS': 5000000,
    'SIR': 1.0,
    'RSI': 30.0,
    'BF': 0.12,
    'ADV': 5000000,
    'PUBLIC': 14000000,
    'PRICE_PER_SHARE': 20.0,
    'SS': 0
}

df_sim_amc = simulate_days(seed_amc, days=30, force_squeeze=True) # will just put force_squeeze = false or true in the future
print(f"SIR value is ", seed_amc['SHORTS']/ seed_amc['ADV'])
filename = os.path.join(folder, f"{seed_amc['TICKER']}.csv")
df_sim_amc.to_csv(filename, index=False)
print(f"Simulation complete. Results saved to {filename}")
# Out:
# SIR value is  1.0
# Simulation complete. Results saved to data/AMC.csv

# %% [markdown]
# ## AAPL

# %%
# creating seed for aapl 2021-05-01,AAPL,Apple Inc.,500000000,25,50,0.10,30000000,480000000,100.0,0

seed_aapl ={   
    'DAY': 0,
    'TICKER': 'AAPL',
    'COMPANY_NAME': 'Apple Inc.',
    'TOTAL_SHARES': 500000000,
    'SHORTS': 15000000,
    'SIR': 0.50,
    'RSI': 50.0,
    'BF': 0.10,
    'ADV': 30000000,
    'PUBLIC': 480000000,
    'PRICE_PER_SHARE': 100.0,
    'SS': 0
}
df_sim_aapl = simulate_days(seed_aapl, days=30, force_squeeze=False)
print(f"SIR value is ", seed_aapl['SHORTS']/ seed_aapl['ADV'])
filename = os.path.join(folder, f"{seed_aapl['TICKER']}.csv")
df_sim_aapl.to_csv(filename, index=False)
print(f"Simulation complete. Results saved to {filename}")
# Out:
# SIR value is  0.5
# Simulation complete. Results saved to data/AAPL.csv

# %% [markdown]
# ## AMD

# %%
seed_amd = {
    'DAY': 0,
    'TICKER': 'AMD',
    'COMPANY_NAME': 'Advanced Micro Devices Inc.',
    'TOTAL_SHARES': 190000000,
    'SHORTS': 23000000,       # The "23" in your example likely means 23 million shorts
    'SIR': 0.76,
    'RSI': 50.0,
    'BF': 0.10,
    'ADV': 30000000,
    'PUBLIC': 170000000,
    'PRICE_PER_SHARE': 100.0,
    'SS': 0
}

df_sim_amd = simulate_days(seed_amd, days=30, force_squeeze=False)
print(f"SIR value is ", seed_amd['SHORTS']/ seed_amd['ADV'])
filename = os.path.join(folder, f"{seed_amd['TICKER']}.csv")
df_sim_amd.to_csv(filename, index=False)
print(f"Simulation complete. Results saved to {filename}")
# Out:
# SIR value is  0.7666666666666667
# Simulation complete. Results saved to data/AMD.csv

# %% [markdown]
# ## Amazon

# %%
# Example seed provided in your query
seed_amzn = {
    'DAY': 0,
    'TICKER': 'AMZN',
    'COMPANY_NAME': 'Amazon.com Inc.',
    'TOTAL_SHARES': 250000000,
    'SHORTS': 23000000,
    'SIR': 0.10,
    'RSI': 50,
    'BF': 0.10,
    'ADV': 30000000,
    'PUBLIC': 230000000,
    'PRICE_PER_SHARE': 100.0,
    'SS': 0
}

df_sim_amzn = simulate_days(seed_amzn, days=30, force_squeeze=False)
print(f"SIR value is ", seed_amzn['SHORTS']/ seed_amzn['ADV'])
filename = os.path.join(folder, f"{seed_amzn['TICKER']}.csv")
df_sim_amzn.to_csv(filename, index=False)
print(f"Simulation complete. Results saved to {filename}")
# Out:
# SIR value is  0.7666666666666667
# Simulation complete. Results saved to data/AMZN.csv

# %% [markdown]
# ## BlackBerry

# %%
seed_bb = {
    'DAY': 0,
    'TICKER': 'BB',
    'COMPANY_NAME': 'BlackBerry Limited',
    'TOTAL_SHARES': 200000000,
    'SHORTS': 9000000,
    'SIR': 0.10,
    'RSI': 20,
    'BF': 0.10,
    'ADV': 5000000,
    'PUBLIC': 195000000,
    'PRICE_PER_SHARE': 10.0,
    'SS': 0
}

df_sim_bb = simulate_days(seed_bb, days=30, force_squeeze=True)
print(f"SIR value is ", seed_bb['SHORTS']/ seed_bb['ADV'])
filename = os.path.join(folder, f"{seed_bb['TICKER']}.csv")
df_sim_bb.to_csv(filename, index=False)
print(f"Simulation complete. Results saved to {filename}")
# Out:
# SIR value is  1.8
# Simulation complete. Results saved to data/BB.csv

# %% [markdown]
# ## Beyond Meat

# %%
seed_bynd = {
    'DAY': 0,
    'TICKER': 'BYND',
    'COMPANY_NAME': 'Beyond Meat Inc.',
    'TOTAL_SHARES': 150000000,
    'SHORTS': 9000000,
    'SIR': 0.10,
    'RSI': 20,
    'BF': 0.10,
    'ADV': 5000000,
    'PUBLIC': 145000000,
    'PRICE_PER_SHARE': 10.0,
    'SS': 0
}

df_sim_bynd = simulate_days(seed_bynd, days=30, force_squeeze=True)
print(f"SIR value is ", seed_bynd['SHORTS']/ seed_bynd['ADV'])
filename = os.path.join(folder, f"{seed_bynd['TICKER']}.csv")
df_sim_bynd.to_csv(filename, index=False)
print(f"Simulation complete. Results saved to {filename}")
# Out:
# SIR value is  1.8
# Simulation complete. Results saved to data/BYND.csv

# %% [markdown]
# ## Fubo TV

# %%
seed_fubo = {
    'DAY': 0,
    'TICKER': 'FUBO',
    'COMPANY_NAME': 'fuboTV Inc.',
    'TOTAL_SHARES': 140000000,
    'SHORTS': 900000,
    'SIR': 0.10,
    'RSI': 20,
    'BF': 0.10,
    'ADV': 5000000,
    'PUBLIC': 135000000,
    'PRICE_PER_SHARE': 10.0,
    'SS': 0
}

df_sim_fubo = simulate_days(seed_fubo, days=30, force_squeeze=True)
print(f"SIR value is ", seed_fubo['SHORTS']/ seed_fubo['ADV'])
filename = os.path.join(folder, f"{seed_fubo['TICKER']}.csv")
df_sim_fubo.to_csv(filename, index=False)
print(f"Simulation complete. Results saved to {filename}")
# Out:
# SIR value is  0.18
# Simulation complete. Results saved to data/FUBO.csv

# %% [markdown]
# ## Microsoft

# %%
seed_msft = {
    'DAY': 0,
    'TICKER': 'MSFT',
    'COMPANY_NAME': 'Microsoft Corporation',
    'TOTAL_SHARES': 7500000000,
    'SHORTS': 9000000,
    'SIR': 0.12,
    'RSI': 35.0,
    'BF': 0.07,
    'ADV': 35000000,
    'PUBLIC': 6600000000,
    'PRICE_PER_SHARE': 320.0,
    'SS': 0
}

df_sim_msft = simulate_days(seed_msft, days=30, force_squeeze=False)
print(f"SIR value is ", seed_msft['SHORTS']/ seed_msft['ADV'])
filename = os.path.join(folder, f"{seed_msft['TICKER']}.csv")
df_sim_msft.to_csv(filename, index=False)
print(f"Simulation complete. Results saved to {filename}")
# Out:
# SIR value is  0.2571428571428571
# Simulation complete. Results saved to data/MSFT.csv

# %% [markdown]
# ## Tesla

# %%
seed_tsla = {
    'DAY': 0,
    'TICKER': 'TSLA',
    'COMPANY_NAME': 'Tesla, Inc.',
    'TOTAL_SHARES': 1000000000,
    'SHORTS': 20000000,
    'SIR': 0.25,
    'RSI': 40.0,
    'BF': 0.12,
    'ADV': 50000000,
    'PUBLIC': 800000000,
    'PRICE_PER_SHARE': 700.0,
    'SS': 0
}

df_sim_tsla = simulate_days(seed_tsla, days=30, force_squeeze=False)
print(f"SIR value is ", seed_tsla['SHORTS']/ seed_tsla['ADV'])
filename = os.path.join(folder, f"{seed_tsla['TICKER']}.csv")
df_sim_tsla.to_csv(filename, index=False)
print(f"Simulation complete. Results saved to {filename}")
# Out:
# SIR value is  0.4
# Simulation complete. Results saved to data/TSLA.csv

# %% [markdown]
# ## NVIDIA

# %%
seed_nvda = {
    'DAY': 0,
    'TICKER': 'NVDA',
    'COMPANY_NAME': 'NVIDIA Corporation',
    'TOTAL_SHARES': 2700000000,
    'SHORTS': 10000000,
    'SIR': 0.18,
    'RSI': 45.0,
    'BF': 0.09,
    'ADV': 25000000,
    'PUBLIC': 2300000000,
    'PRICE_PER_SHARE': 500.0,
    'SS': 0
}

df_sim_nvda = simulate_days(seed_nvda, days=30, force_squeeze=False)
print(f"SIR value is ", seed_nvda['SHORTS']/ seed_nvda['ADV'])
filename = os.path.join(folder, f"{seed_nvda['TICKER']}.csv")
df_sim_nvda.to_csv(filename, index=False)
print(f"Simulation complete. Results saved to {filename}")
# Out:
# SIR value is  0.4
# Simulation complete. Results saved to data/NVDA.csv

# %% [markdown]
# ## Google

# %%
seed_googl = {
    'DAY': 0,
    'TICKER': 'GOOGL',
    'COMPANY_NAME': 'Alphabet Inc.',
    'TOTAL_SHARES': 670000000,
    'SHORTS': 8500000,
    'SIR': 0.20,
    'RSI': 48.0,
    'BF': 0.11,
    'ADV': 22000000,
    'PUBLIC': 580000000,
    'PRICE_PER_SHARE': 2700.0,
    'SS': 0
}

df_sim_googl = simulate_days(seed_googl, days=30, force_squeeze=False)
print(f"SIR value is ", seed_googl['SHORTS']/ seed_googl['ADV'])
filename = os.path.join(folder, f"{seed_googl['TICKER']}.csv")
df_sim_googl.to_csv(filename, index=False)
print(f"Simulation complete. Results saved to {filename}")
# Out:
# SIR value is  0.38636363636363635
# Simulation complete. Results saved to data/GOOGL.csv

# %% [markdown]
# ## Pfizer

# %%
seed_pfe = {
    'DAY': 0,
    'TICKER': 'PFE',
    'COMPANY_NAME': 'Pfizer Inc.',
    'TOTAL_SHARES': 6000000000,
    'SHORTS': 10000000,
    'SIR': 0.15,
    'RSI': 38.0,
    'BF': 0.08,
    'ADV': 28000000,
    'PUBLIC': 5600000000,
    'PRICE_PER_SHARE': 45.0,
    'SS': 0
}

df_sim_pfe = simulate_days(seed_pfe, days=30, force_squeeze=True)
print(f"SIR value is ", seed_pfe['SHORTS']/ seed_pfe['ADV'])
filename = os.path.join(folder, f"{seed_pfe['TICKER']}.csv")
df_sim_pfe.to_csv(filename, index=False)
print(f"Simulation complete. Results saved to {filename}")
# Out:
# SIR value is  0.35714285714285715
# Simulation complete. Results saved to data/PFE.csv

# %% [markdown]
# ## JP Morgan

# %%
seed_jpm = {
    'DAY': 0,
    'TICKER': 'JPM',
    'COMPANY_NAME': 'JPMorgan Chase & Co.',
    'TOTAL_SHARES': 3000000000,
    'SHORTS': 4500000,
    'SIR': 0.22,
    'RSI': 42.0,
    'BF': 0.10,
    'ADV': 26000000,
    'PUBLIC': 2550000000,
    'PRICE_PER_SHARE': 140.0,
    'SS': 0
}

df_sim_jpm = simulate_days(seed_jpm, days=30, force_squeeze=False)
print(f"SIR value is ", seed_jpm['SHORTS']/ seed_jpm['ADV'])
filename = os.path.join(folder, f"{seed_jpm['TICKER']}.csv")
df_sim_jpm.to_csv(filename, index=False)
print(f"Simulation complete. Results saved to {filename}")
# Out:
# SIR value is  0.17307692307692307
# Simulation complete. Results saved to data/JPM.csv

# %% [markdown]
# ## Visa

# %%
seed_v = {
    'DAY': 0,
    'TICKER': 'V',
    'COMPANY_NAME': 'Visa Inc.',
    'TOTAL_SHARES': 2200000000,
    'SHORTS': 4500000,
    'SIR': 0.19,
    'RSI': 44.0,
    'BF': 0.07,
    'ADV': 21000000,
    'PUBLIC': 1900000000,
    'PRICE_PER_SHARE': 230.0,
    'SS': 0
}

df_sim_v = simulate_days(seed_v, days=30, force_squeeze=False)
print(f"SIR value is ", seed_v['SHORTS']/ seed_v['ADV'])
filename = os.path.join(folder, f"{seed_v['TICKER']}.csv")
df_sim_v.to_csv(filename, index=False)
print(f"Simulation complete. Results saved to {filename}")
# Out:
# SIR value is  0.21428571428571427
# Simulation complete. Results saved to data/V.csv

# %% [markdown]
# ## Netflix

# %%
seed_nflx = {
    'DAY': 0,
    'TICKER': 'NFLX',
    'COMPANY_NAME': 'Netflix, Inc.',
    'TOTAL_SHARES': 440000000,
    'SHORTS': 2000000,
    'SIR': 0.28,
    'RSI': 48.0,
    'BF': 0.14,
    'ADV': 12000000,
    'PUBLIC': 355000000,
    'PRICE_PER_SHARE': 520.0,
    'SS': 0
}

df_sim_nflx = simulate_days(seed_nflx, days=30, force_squeeze=True)
print(f"SIR value is ", seed_nflx['SHORTS']/ seed_nflx['ADV'])
filename = os.path.join(folder, f"{seed_nflx['TICKER']}.csv")
df_sim_nflx.to_csv(filename, index=False)
print(f"Simulation complete. Results saved to {filename}")
# Out:
# SIR value is  0.16666666666666666
# Simulation complete. Results saved to data/NFLX.csv

# %% [markdown]
# ## McDonalds

# %%
seed_mcd = {
    'DAY': 0,
    'TICKER': 'MCD',
    'COMPANY_NAME': "McDonald's Corporation",
    'TOTAL_SHARES': 760000000,
    'SHORTS': 5500000,
    'SIR': 0.14,
    'RSI': 36.0,
    'BF': 0.06,
    'ADV': 9000000,
    'PUBLIC': 705000000,
    'PRICE_PER_SHARE': 270.0,
    'SS': 0
}

df_sim_mcd = simulate_days(seed_mcd, days=30, force_squeeze=True)
print(f"SIR value is ", seed_mcd['SHORTS']/ seed_mcd['ADV'])
filename = os.path.join(folder, f"{seed_mcd['TICKER']}.csv") 
df_sim_mcd.to_csv(filename, index=False)
print(f"Simulation complete. Results saved to {filename}")
# Out:
# SIR value is  0.6111111111111112
# Simulation complete. Results saved to data/MCD.csv

# %% [markdown]
# ## Disney

# %%
seed_dis = {
    'DAY': 0,
    'TICKER': 'DIS',
    'COMPANY_NAME': 'The Walt Disney Company',
    'TOTAL_SHARES': 1700000000,
    'SHORTS': 12000000,
    'SIR': 0.17,
    'RSI': 40.0,
    'BF': 0.09,
    'ADV': 16000000,
    'PUBLIC': 1460000000,
    'PRICE_PER_SHARE': 100.0,
    'SS': 0
}

df_sim_dis = simulate_days(seed_dis, days=30, force_squeeze=True)
print(f"SIR value is ", seed_dis['SHORTS']/ seed_dis['ADV'])
filename = os.path.join(folder, f"{seed_dis['TICKER']}.csv")
df_sim_dis.to_csv(filename, index=False)
print(f"Simulation complete. Results saved to {filename}")
# Out:
# SIR value is  0.75
# Simulation complete. Results saved to data/DIS.csv

# %% [markdown]
# ## Costco

# %%
seed_cost = {
    'DAY': 0,
    'TICKER': 'COST',
    'COMPANY_NAME': 'Costco Wholesale Corporation',
    'TOTAL_SHARES': 450000000,
    'SHORTS': 6000000,
    'SIR': 0.24,
    'RSI': 45.0,
    'BF': 0.10,
    'ADV': 8500000,
    'PUBLIC': 390000000,
    'PRICE_PER_SHARE': 510.0,
    'SS': 0
}

df_sim_cost = simulate_days(seed_cost, days=30, force_squeeze=False)
print(f"SIR value is ", seed_cost['SHORTS']/ seed_cost['ADV'])
filename = os.path.join(folder, f"{seed_cost['TICKER']}.csv")
df_sim_cost.to_csv(filename, index=False)
print(f"Simulation complete. Results saved to {filename}")
# Out:
# SIR value is  0.7058823529411765
# Simulation complete. Results saved to data/COST.csv

# %% [markdown]
# ## Bank of America

# %%
seed_bac = {
    'DAY': 0,
    'TICKER': 'BAC',
    'COMPANY_NAME': 'Bank of America Corporation',
    'TOTAL_SHARES': 8500000000,
    'SHORTS': 12000000,
    'SIR': 0.16,
    'RSI': 43.0,
    'BF': 0.11,
    'ADV': 35000000,
    'PUBLIC': 7300000000,
    'PRICE_PER_SHARE': 32.0,
    'SS': 0
}
print(f"SIR value is ", seed_bac['SHORTS']/ seed_bac['ADV'])
df_sim_bac = simulate_days(seed_bac, days=30, force_squeeze=False)

filename = os.path.join(folder, f"{seed_bac['TICKER']}.csv")
df_sim_bac.to_csv(filename, index=False)    
print(f"Simulation complete. Results saved to {filename}")
# Out:
# SIR value is  0.34285714285714286
# Simulation complete. Results saved to data/BAC.csv

# %% [markdown]
# ## Coca-Cola

# %%
seed_ko = {
    'DAY': 0,
    'TICKER': 'KO',
    'COMPANY_NAME': 'The Coca-Cola Company',
    'TOTAL_SHARES': 4200000000,
    'SHORTS': 3500000,
    'SIR': 0.23,
    'RSI': 33.0,
    'BF': 0.07,
    'ADV': 14000000,
    'PUBLIC': 3850000000,
    'PRICE_PER_SHARE': 60.0,
    'SS': 0
}
print(f"SIR value is ", seed_ko['SHORTS']/ seed_ko['ADV'])
df_sim_ko = simulate_days(seed_ko, days=30, force_squeeze=True)

filename = os.path.join(folder, f"{seed_ko['TICKER']}.csv")
df_sim_ko.to_csv(filename, index=False)
print(f"Simulation complete. Results saved to {filename}")
# Out:
# SIR value is  0.25
# Simulation complete. Results saved to data/KO.csv

# %% [markdown]
# ## Oracle

# %%
seed_orcl = {
    'DAY': 0,
    'TICKER': 'ORCL',
    'COMPANY_NAME': 'Oracle Corporation',
    'TOTAL_SHARES': 2700000000,
    'SHORTS': 60000000,
    'SIR': 0.10,  # Shorts to ADV ratio: shorts 60M, ADV 600M (10x ADV)
    'RSI': 40.0,
    'BF': 0.08,
    'ADV': 60000000,
    'PUBLIC': 2600000000,
    'PRICE_PER_SHARE': 85.0,
    'SS': 0
}

df_sim_orcl = simulate_days(seed_orcl, days=30, force_squeeze=False)
print(f"SIR value is ", seed_orcl['SHORTS']/ seed_orcl['ADV'])

filename = os.path.join(folder, f"{seed_orcl['TICKER']}.csv")
df_sim_orcl.to_csv(filename, index=False)
print(f"Simulation complete. Results saved to {filename}")
# Out:
# SIR value is  1.0
# Simulation complete. Results saved to data/ORCL.csv

# %% [markdown]
# ## Altria

# %%
seed_mo = {
    'DAY': 0,
    'TICKER': 'MO',
    'COMPANY_NAME': 'Altria Group, Inc.',
    'TOTAL_SHARES': 4400000000,
    'SHORTS': 40000000,
    'SIR': 0.14,  # Shorts to ADV ratio: 40M shorts, 280M ADV (7x ADV)
    'RSI': 35.0,
    'BF': 0.06,
    'ADV': 280000000,
    'PUBLIC': 4200000000,
    'PRICE_PER_SHARE': 46.0,
    'SS': 0
}

df_sim_mo = simulate_days(seed_mo, days=30, force_squeeze=False)

filename = os.path.join(folder, f"{seed_mo['TICKER']}.csv")
df_sim_mo.to_csv(filename, index=False)
print(f"Simulation complete. Results saved to {filename}")
# Out:
# Simulation complete. Results saved to data/MO.csv

# %% [markdown]
# ## Chevron

# %%
seed_cvx = {
    'DAY': 0,
    'TICKER': 'CVX',
    'COMPANY_NAME': 'Chevron Corporation',
    'TOTAL_SHARES': 1900000000,
    'SHORTS': 85000000,
    'SIR': 0.11,  # Shorts to ADV ratio: 85M shorts, 780M ADV (~9x ADV)
    'RSI': 39.0,
    'BF': 0.07,
    'ADV': 780000000,
    'PUBLIC': 1820000000,
    'PRICE_PER_SHARE': 160.0,
    'SS': 0
}

df_sim_cvx = simulate_days(seed_cvx, days=30, force_squeeze=True)

filename = os.path.join(folder, f"{seed_cvx['TICKER']}.csv")
df_sim_cvx.to_csv(filename, index=False)
print(f"Simulation complete. Results saved to {filename}")
# Out:
# Simulation complete. Results saved to data/CVX.csv

# %% [markdown]
# ## Adobe

# %%
seed_adbe = {
    'DAY': 0,
    'TICKER': 'ADBE',
    'COMPANY_NAME': 'Adobe Inc.',
    'TOTAL_SHARES': 550000000,
    'SHORTS': 30000000,
    'SIR': 0.15,  # Shorts to ADV ratio: 30M shorts, 200M ADV (~6.7x ADV)
    'RSI': 41.0,
    'BF': 0.08,
    'ADV': 200000000,
    'PUBLIC': 520000000,
    'PRICE_PER_SHARE': 500.0,
    'SS': 0
}

filename = "data/" + f"{seed_adbe['TICKER']}.csv"
df_sim_adbe = simulate_days(seed_adbe, days=30, force_squeeze=True)
df_sim_adbe.to_csv(filename, index=False)
print(f"Simulation complete. Results saved to {filename}")
# Out:
# Simulation complete. Results saved to data/ADBE.csv

# %% [markdown]
# # GME

# %%
# GME seed, GameStop Corp.
seed_gme = {
    'DAY': 0,
    'TICKER': 'GME',
    'COMPANY_NAME': 'GameStop Corp.',
    'TOTAL_SHARES': 447908690,
    'SHORTS': 494679089,
    'SIR': 0.226,
    'RSI': 53.13,
    'BF': 0.226,
    'ADV': 46895360.0,
    'PUBLIC': 408656827,
    'PRICE_PER_SHARE': 4.31,
    'SS': 0
}
filename = "data/" + f"{seed_gme['TICKER']}.csv"
df_sim_gme = simulate_days(seed_gme, days=30, force_squeeze=True)
df_sim_gme.to_csv(filename, index=False)
print(f"Simulation complete. Results saved to {filename}")
# Out:
# Simulation complete. Results saved to data/GME.csv
